# %% [markdown]
# # Machine Learning Workshop
# ### Remote
# ### 18th March 2023
#
# _____
# # Project 1 - Used Vehicle Price Prediction
#
# by [Jesus Solano](https://linkedin.com/in/jesus-solano-go) and [Alejandro Correa Bahnsen](albahnsen.com/)
#
# version 1.4, March 2023
#
# This notebook is licensed under a [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US). Special thanks goes to [Rick Muller](http://www.cs.sandia.gov/~rmuller/), Sandia National Laboratories
# ____

# %% [markdown]
# ## Introduction
#
# - 1.2 Million listings scraped from TrueCar.com - Price, Mileage, Make, Model dataset from Kaggle: [data](https://www.kaggle.com/jpayne/852k-used-car-listings)
# - Each observation represents the price of an used car
#
# ![Used Vehicles Bogota](https://www.revistaturbo.com/wp-content/uploads/2021/08/feria_de_autos_usados.jpg)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://github.com/albahnsen/PracticalMachineLearningClass/raw/master/datasets/dataTrain_carListings.zip')

# %%
data.head()
# Out:
#    Price  Year  Mileage State       Make        Model
# 0  21490  2014    31909    MD     Nissan    MuranoAWD
# 1  21250  2016    25741    KY  Chevrolet  CamaroCoupe
# 2  20925  2016    24633    SC    Hyundai        Santa
# 3  14500  2012    84026    OK       Jeep        Grand
# 4  32488  2013    22816    TN       Jeep     Wrangler

# %%
data.shape
# Out:
# (500000, 6)

# %%
data.Price.describe()
# Out:
# count    500000.000000
# mean      21144.186304
# std       10753.259704
# min        5001.000000
# 25%       13499.000000
# 50%       18450.000000
# 75%       26998.000000
# max       79999.000000
# Name: Price, dtype: float64

# %%
data.plot(kind='scatter', y='Price', x='Year')
plt.show()

# %%
data.plot(kind='scatter', y='Price', x='Mileage')
plt.show()

# %%
data.columns
# Out:
# Index(['Price', 'Year', 'Mileage', 'State', 'Make', 'Model'], dtype='object')

# %% [markdown]
# # Exercise P1.1 (90%)
#
# Develop a machine learning model that predicts the price of the of car using as an input ['Year', 'Mileage', 'State', 'Make', 'Model']
#
# #### Evaluation:
# - Performance of the model in the test dataset.

# %%
data_test = pd.read_csv('https://github.com/albahnsen/PracticalMachineLearningClass/raw/master/datasets/dataTest_carListings.zip', index_col=0)

# %%
data_test.head()
# Out:
#     Year  Mileage State    Make       Model
# ID
# 0   2015    23388    OH    Ford   EscapeFWD
# 1   2014    45061    PA    Ford    EscapeSE
# 2   2007   101033    WI  Toyota    Camry4dr
# 3   2015    13590    HI    Jeep    Wrangler
# 4   2009   118916    CO   Dodge  Charger4dr

# %%
data_test.shape
# Out:
# (250000, 5)

# %% [markdown]
# # Exercise P1.2 (10%)
#
# Present your approach to the class showing the relevant techniques you used to get the best performance.
#
# #### Evaluation:
# - Oral presentation.
